# %%
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
import time
import os
import pandas as pd

# %%
def capture_bhuvan_map_canvas(url, output='map_canvas.png', width=1920, height=1080):
    print(f"Capturing map canvas from: {url}")
    print(f"Saving to: {output}")

    options = Options()
    options.headless = True

    service = Service("geckodriver.exe")

    driver = webdriver.Firefox(service=service, options=options)
    driver.set_window_size(width, height)

    driver.get(url)
    time.sleep(6)  

    try:

        canvas = driver.find_element(By.CLASS_NAME, "maplibregl-canvas")
        canvas.screenshot(output)
        print(f"✅ Map screenshot saved as {output}")
    except Exception as e:
        print("❌ Could not locate canvas element.")
        print(f"Error: {e}")
        fallback = output.replace(".png", "_full.png")
        driver.save_screenshot(fallback)
        print(f"Fallback full screenshot saved: {fallback}")

    driver.quit()

# %%
capture_bhuvan_map_canvas(
    "https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/17.234223/78.42943",
    output="airport_map.png"
)
# Out:
# Capturing map canvas from: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/17.234223/78.42943
# Saving to: airport_map.png
# ✅ Map screenshot saved as airport_map.png

# %%
def capture_multiple_bhuvan_screenshots(urls, output_dir='screenshots', width=1920, height=1080):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    options = Options()
    options.headless = True
    service = Service("geckodriver.exe")

    driver = webdriver.Firefox(service=service, options=options)
    driver.set_window_size(width, height)

    for idx, url in enumerate(urls, start=1):
        print(f"\n📍 Processing {idx}/{len(urls)}: {url}")
        driver.get(url)
        time.sleep(6)  # Wait for map to load

        try:
            canvas = driver.find_element(By.CLASS_NAME, "maplibregl-canvas")
            output_path = os.path.join(output_dir, f"map_{idx}.png")
            canvas.screenshot(output_path)
            print(f"✅ Saved canvas screenshot: {output_path}")
        except Exception as e:
            print(f"❌ Could not locate canvas element for URL {idx}")
            fallback_path = os.path.join(output_dir, f"map_{idx}_full.png")
            driver.save_screenshot(fallback_path)
            print(f"⚠️ Fallback full screenshot saved: {fallback_path}")

    driver.quit()
    print("\n All screenshots captured and browser closed.")

# %%
urls = [
    "https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/17.234223/78.42943",
    "https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/12.994/80.170",
    "https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/17.711/83.284",
    "https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/17.621/83.2298",
    "https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/21.08/72.63"
]


capture_multiple_bhuvan_screenshots(urls,output_dir="ops")
# Out:
# 📍 Processing 1/5: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/17.234223/78.42943
# ✅ Saved canvas screenshot: ops\map_1.png
#
# 📍 Processing 2/5: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/12.994/80.170
# ✅ Saved canvas screenshot: ops\map_2.png
#
# 📍 Processing 3/5: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/17.711/83.284
# ✅ Saved canvas screenshot: ops\map_3.png
#
# 📍 Processing 4/5: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/17.621/83.2298
# ✅ Saved canvas screenshot: ops\map_4.png
#
# 📍 Processing 5/5: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/21.08/72.63
# ✅ Saved canvas screenshot: ops\map_5.png
#
# 🎉 All screenshots captured and browser closed.

# %%
df = pd.read_excel("Required data list.xlsx")
df.head(5)
# Out:
#                         City     Type  Latitude  Longitude
# 0  Kandla(Deendayal), Gujrat  Seaport   23.0172    70.2125
# 1                     Cochin  Seaport    9.9546    76.2678
# 2                     Cochin  Airport   10.1532    76.3933
# 3                    Chennai  Seaport   13.0844    80.2899
# 4                    Chennai  Airport   12.9940    80.1707

# %%
url = 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15'

for Lat,Long in zip(df['Latitude'],df['Longitude']):
    url_i = url + '/' + str(Lat) + '/' + str(Long)
    print(url_i)
# Out:
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/23.0172/70.2125
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/9.9546/76.2678
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/10.1532/76.3933
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/13.0844/80.2899
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/12.994/80.1707
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/17.711/83.284
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/17.621/83.2298
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/21.08/72.63
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/23.0764/72.631
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/13.1989/77.7069
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/22.6536/88.4451
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/15.4088/73.80111111
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/20.2817/86.6727
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/8.4871/76.922
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/28.5686/77.1122
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/17.23/78.432
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/19.097/72.8742
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/18.9/72.816
# https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15/8.3742/76.9882

# %%
capture_bhuvan_map_canvas(
    "https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.4/28.5686/77.1122",
    output="airport_map.png"
)
# Out:
# Capturing map canvas from: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.4/28.5686/77.1122
# Saving to: airport_map.png
# ✅ Map screenshot saved as airport_map.png

# %%
def capture_bhuvan_map_canvas_button(url, output='map_canvas.png', width=1920, height=1080):
    print(f"Capturing map canvas from: {url}")
    print(f"Saving to: {output}")

    options = Options()
    options.headless = True

    service = Service("geckodriver.exe")

    driver = webdriver.Firefox(service=service, options=options)
    driver.set_window_size(width, height)

    driver.get(url)
    time.sleep(6)  # Wait for map and elements to load

    try:
        # Click the button before taking screenshot
        button = driver.find_element(By.XPATH, "/html/body/div[1]/div[1]/button")
        button.click()
        time.sleep(2)  # wait for UI to update after clicking

        # Capture the canvas
        canvas = driver.find_element(By.CLASS_NAME, "maplibregl-canvas")
        canvas.screenshot(output)
        print(f"✅ Map screenshot saved as {output}")

    except Exception as e:
        print("❌ Could not locate canvas element.")
        print(f"Error: {e}")
        fallback = output.replace(".png", "_full.png")
        driver.save_screenshot(fallback)
        print(f"⚠️ Fallback full screenshot saved: {fallback}")

    driver.quit()

# %%
capture_bhuvan_map_canvas_button(
    "https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.4/28.5686/77.1122",
    output="airport_map.png"
)
# Out:
# Capturing map canvas from: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.4/28.5686/77.1122
# Saving to: airport_map.png
# ✅ Map screenshot saved as airport_map.png

# %%
def capture_multiple_bhuvan_screenshots(urls, names, output_dir='screenshots' , width=1920, height=1080):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    options = Options()
    options.headless = True
    service = Service("geckodriver.exe")

    driver = webdriver.Firefox(service=service, options=options)
    driver.set_window_size(width, height)

    for idx, url in enumerate(urls, start=1):
        print(f"\n📍 Processing {idx}/{len(urls)}: {url}")
        driver.get(url)
        time.sleep(6)  # Wait for map to load

        try:
            canvas = driver.find_element(By.CLASS_NAME, "maplibregl-canvas")
            output_path = os.path.join(output_dir, f"{names[idx-1]}.png")
            canvas.screenshot(output_path)
            print(f"✅ Saved canvas screenshot: {output_path}")
        except Exception as e:
            print(f"❌ Could not locate canvas element for URL {idx}")
            fallback_path = os.path.join(output_dir, f"{name-1}_full.png")
            driver.save_screenshot(fallback_path)
            print(f"⚠️ Fallback full screenshot saved: {fallback_path}")

    driver.quit()
    print("\n All screenshots captured and browser closed.")

# %%
df= pd.read_excel("Required data list new.xlsx")
df.head()
# Out:
#             City     Type   Latitude  Longitude   Zoom   Drop     Num  \
# 0   Ahmedbad_air  Airport  23.071908  72.622873  15.33  False     NaN
# 1  Bengaluru_air  Airport  13.201950  77.701164  15.20  False     NaN
# 2    Chennai_air  Airport  12.988160  80.167310  15.00  False     NaN
# 3     Cochin_air  Airport  10.154260  76.397210  15.00   True  2025.0
# 4    Delhi_air_a  Airport  28.562810  77.099340  14.80   True  2025.0
#
#                                           link_layer
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  &layer2=High+Resolution+Data+(1m)%3AJAN-JUN+20...
# 4  &layer2=High+Resolution+Data+(1m)%3AJAN-JUN+20...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        56 non-null     object
#  1   Type        56 non-null     object
#  2   Latitude    56 non-null     float64
#  3   Longitude   56 non-null     float64
#  4   Zoom        56 non-null     float64
#  5   Drop        56 non-null     bool
#  6   Num         11 non-null     float64
#  7   link_layer  11 non-null     object
# dtypes: bool(1), float64(4), object(3)
# memory usage: 3.2+ KB

# %%
url = 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#'
urls=[]
names=[]
for Lat,Long,drop,zoom,name in zip(df['Latitude'],df['Longitude'],df['Drop'],df['Zoom'],df['City']):
    if drop == False:
        url_i = url +str(zoom)+ '/' + str(Lat) + '/' + str(Long)
        urls.append(url_i)
        names.append(name)
print(urls,names)
# Out:
# ['https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.33/23.071908/72.622873', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.2/13.20195/77.701164', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/12.98816/80.16731', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.3/17.234269/78.436037', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.8/22.64575/88.44829', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/19.09157/72.86411', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/8.48229/76.92321', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.33/26.763504/80.888015', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.67/26.105694/91.584481', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.5/20.250122/85.816693', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.2/34.000663/74.761732', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.2/30.676495/76.786808', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.48/25.450904/82.857867', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/25.593168/85.090986', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.73/22.725949/75.805729', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.5/11.138682/75.950432', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.81/11.028628/77.04305', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.6/26.68446/88.3268', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.67/21.119658/72.745755', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.76/24.618861/73.895636', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.8/23.288095/77.33874', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/23.888891/91.242379', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.4/32.683019/74.840734', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.67/24.764173/93.898159', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.8/9.835729/78.090528', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.64/16.525919/80.794677', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/13.10617/80.30735', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/13.09309/80.30023', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/9.96381/76.27508', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/9.95064/76.28014', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/13.26656/80.34247', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.7/22.0324/88.0877', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/21.08194/72.62987', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/23.02674/70.22894', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/23.00914/70.22968', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/22.98751/70.23195', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.9/12.9256/74.82512', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/15.4088/73.80111111', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.2/18.89497/72.85915', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.17/18.942544/72.842736', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.5/22.73979/69.70958', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/20.2754/86.67236', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/20.25964/86.67534', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/21.08/72.63', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/17.70101/83.28327'] ['Ahmedbad_air', 'Bengaluru_air', 'Chennai_air', 'Hyderabad_air', 'Kolkata_air', 'Mumbai_air', 'Thiruvananthpuram_air', 'Lucknow_air', 'Guwahati_air', 'Bhubaneswar_air', 'Srinagar_air', 'Chandigarh_air', 'Varanasi_air', 'Patna_air', 'Indore_air', 'Kozhikode_air', 'Coimbatore_air', 'Siligudi_air', 'Surat_air', 'Udaipur_air', 'Bhopal_air', 'Agartala_air', 'Jammu_air', 'Imphal_air', 'Madurai_air', 'Vijaywada_air', 'Chennai_sea_a', 'Chennai_sea_b', 'Cochin_sea_a', 'Cochin_sea_b', 'Ennore_sea', 'Haldia_bengal_sea', 'Hazira_guj_sea', 'Kandla_Gujrat_sea_a', 'Kandla_Gujrat_sea_b', 'Ka ...

# %%
len(urls),len(names)
# Out:
# (45, 45)

# %%
capture_multiple_bhuvan_screenshots(urls,names, output_dir='screenshots')
# Out:
# 📍 Processing 1/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/23.07415/73.62716
# ✅ Saved canvas screenshot: screenshots\Ahmedbad_air.png
#
# 📍 Processing 2/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.2/13.20195/77.701164
# ✅ Saved canvas screenshot: screenshots\Bengaluru_air.png
#
# 📍 Processing 3/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/12.98816/80.16731
# ✅ Saved canvas screenshot: screenshots\Chennai_air.png
#
# 📍 Processing 4/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.3/17.234269/78.436037
# ✅ Saved canvas screenshot: screenshots\Hyderabad_air.png
#
# 📍 Processing 5/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.8/22.64575/88.44829
# ✅ Saved canvas screenshot: screenshots\Kolkata_air.png
#
# 📍 Processing 6/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/19.09157/72.86411
# ✅ Saved canvas screenshot: screenshots\Mumbai_air.png
#
# 📍 Processing 7/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/8.48229/76.92321
# ✅ Saved canvas screenshot: screenshots\Thiruvananthpuram_air.png
#
# 📍 Processing 8/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.33/26.763504/80.888015
# ✅ Saved canvas screenshot: screenshots\Lucknow_air.png
#
# 📍 Processing 9/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.67/26.105694/91.584481
# ✅ Saved canvas screenshot: screenshots\Guwahati_air.png
#
# 📍 Processing 10/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.5/20.250122/85.816693
# ✅ Saved canvas screenshot: screenshots\Bhubaneswar_air.png
#
# 📍 Processing 11/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.2/34.000663/74.761732
# ✅ Saved canvas screenshot: screenshots\Srinagar_air.png
#
# 📍 Processing 12/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.2/30.676495/76.786808
# ✅ Saved canvas screenshot: screenshots\Chandigarh_air.png
#
# 📍 Processing 13/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.48/25.450904/82.857867
# ✅ Saved canvas screenshot: screenshots\Varanasi_air.png
#
# 📍 Processing 14/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/25.593168/85.090986
# ✅ Saved canvas screenshot: screenshots\Patna_air.png
#
# 📍 Processing 15/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.73/22.725949/75.805729
# ✅ Saved canvas screenshot: screenshots\Indore_air.png
#
# 📍 Processing 16/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.5/11.138682/75.950432
# ✅ Saved canvas screenshot: screenshots\Kozhikode_air.png
#
# 📍 Processing 17/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.81/11.028628/77.04305
# ✅ Saved canvas screenshot: screenshots\Coimbatore_air.png
#
# 📍 Processing 18/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.6/26.68446/88.3268
# ✅ Saved canvas screenshot: screenshots\Siligudi_air.png
#
# 📍 Processing 19/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.67/21.119658/72.745755
# ✅ Saved canvas screenshot: screenshots\Surat_air.png
#
# 📍 Processing 20/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.76/24.618861/73.895636
# ✅ Saved canvas screenshot: screenshots\Udaipur_air.png
#
# 📍 Processing 21/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.8/23.288095/77.33874
# ✅ Saved canvas screenshot: screenshots\Bhopal_air.png
#
# 📍 Processing 22/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.57/23.888891/91.242379
# ✅ Saved canvas screenshot: screenshots\Agartala_air.png
#
# 📍 Processing 23/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.4/32.683019/74.840734
# ✅ Saved canvas screenshot: screenshots\Jammu_air.png
#
# 📍 Processing 24/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.67/24.764173/93.898159
# ✅ Saved canvas screenshot: screenshots\Imphal_air.png
#
# 📍 Processing 25/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.8/9.835729/78.090528
# ✅ Saved canvas screenshot: screenshots\Madurai_air.png
#
# 📍 Processing 26/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.64/16.525919/80.794677
# ✅ Saved canvas screenshot: screenshots\Vijaywada_air.png
#
# 📍 Processing 27/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/13.10617/80.30735
# ✅ Saved canvas screenshot: screenshots\Chennai_sea_a.png
#
# 📍 Processing 28/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/13.09309/80.30023
# ✅ Saved canvas screenshot: screenshots\Chennai_sea_b.png
#
# 📍 Processing 29/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/9.96381/76.27508
# ✅ Saved canvas screenshot: screenshots\Cochin_sea_a.png
#
# 📍 Processing 30/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/9.95064/76.28014
# ✅ Saved canvas screenshot: screenshots\Cochin_sea_b.png
#
# 📍 Processing 31/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/13.26656/80.34247
# ✅ Saved canvas screenshot: screenshots\Ennore_sea.png
#
# 📍 Processing 32/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.7/22.0324/88.0877
# ✅ Saved canvas screenshot: screenshots\Haldia_bengal_sea.png
#
# 📍 Processing 33/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/21.08194/72.62987
# ✅ Saved canvas screenshot: screenshots\Hazira_guj_sea.png
#
# 📍 Processing 34/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/23.02674/70.22894
# ✅ Saved canvas screenshot: screenshots\Kandla_Gujrat_sea_a.png
#
# 📍 Processing 35/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/23.00914/70.22968
# ✅ Saved canvas screenshot: screenshots\Kandla_Gujrat_sea_b.png
#
# 📍 Processing 36/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/22.98751/70.23195
# ✅ Saved canvas screenshot: screenshots\Kandla_Gujrat_sea_c.png
#
# 📍 Processing 37/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.9/12.9256/74.82512
# ✅ Saved canvas screenshot: screenshots\Mangalore_new_sea.png
#
# 📍 Processing 38/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/15.4088/73.80111111
# ✅ Saved canvas screenshot: screenshots\Mormugao_Goa_sea.png
#
# 📍 Processing 39/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.2/18.89497/72.85915
# ✅ Saved canvas screenshot: screenshots\Mumbai_sea_a.png
#
# 📍 Processing 40/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.5/18.93618/72.83617
# ✅ Saved canvas screenshot: screenshots\Mumbai_sea_b.png
#
# 📍 Processing 41/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#14.5/22.73979/69.70958
# ✅ Saved canvas screenshot: screenshots\Mundra_guj_sea.png
#
# 📍 Processing 42/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/20.2754/86.67236
# ✅ Saved canvas screenshot: screenshots\Paradeep_Odisha_sea_a.png
#
# 📍 Processing 43/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/20.25964/86.67534
# ✅ Saved canvas screenshot: screenshots\Paradeep_Odisha_sea_b.png
#
# 📍 Processing 44/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/21.08/72.63
# ✅ Saved canvas screenshot: screenshots\Surat_sea.png
#
# 📍 Processing 45/45: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.0/17.70101/83.28327
# ✅ Saved canvas screenshot: screenshots\Vishakhapatanam_sea.png
#
# 🎉 All screenshots captured and browser closed.

# %%
capture_multiple_bhuvan_screenshots(['https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.33/23.071908/72.622873'],['Ahmedbad_air'], output_dir='screenshots')
# Out:
# 📍 Processing 1/1: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.33/23.071908/72.622873
# ✅ Saved canvas screenshot: screenshots\Ahmedbad_air.png
#
# 🎉 All screenshots captured and browser closed.

# %%
capture_multiple_bhuvan_screenshots(['https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.17/18.942544/72.842736'],['Mumbai_sea_b'], output_dir='screenshots')
# Out:
# 📍 Processing 1/1: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.17/18.942544/72.842736
# ✅ Saved canvas screenshot: screenshots\Mumbai_sea_b.png
#
# 🎉 All screenshots captured and browser closed.

# %%
def capture_multiple_bhuvan_with_button(urls, names, output_dir='screenshots', width=1920, height=1080):
    print("Starting Bhuvan screenshot capture with button click...")

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    options = Options()
    options.headless = True
    service = Service("geckodriver.exe")

    driver = webdriver.Firefox(service=service, options=options)
    driver.set_window_size(width, height)

    for idx, url in enumerate(urls):
        print(f"\n📍 Processing {idx + 1}/{len(urls)}: {url}")
        driver.get(url)
        time.sleep(6)  # Let the map and UI load

        try:
            # Click the UI button if present
            button = driver.find_element(By.XPATH, "/html/body/div[1]/div[1]/button")
            button.click()
            time.sleep(2)
        except Exception as e:
            print("⚠️ Button click failed or not found, continuing...")

        try:
            canvas = driver.find_element(By.CLASS_NAME, "maplibregl-canvas")
            output_path = os.path.join(output_dir, f"{names[idx]}.png")
            canvas.screenshot(output_path)
            print(f"✅ Saved canvas screenshot: {output_path}")
        except Exception as e:
            print(f"❌ Could not locate canvas element.")
            fallback = os.path.join(output_dir, f"{names[idx]}_full.png")
            driver.save_screenshot(fallback)
            print(f"⚠️ Fallback full screenshot saved: {fallback}")

    driver.quit()
    print("\n🎉 All screenshots captured and browser closed.")

# %%
url = 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite'
urls_buttons=[]
names_buttons=[]
for Lat,Long,drop,zoom,name,layer in zip(df['Latitude'],df['Longitude'],df['Drop'],df['Zoom'],df['City'],df['link_layer']):
    if drop == True:
        url_i = url + layer +'#'+str(zoom)+ '/' + str(Lat) + '/' + str(Long)
        urls_buttons.append(url_i)
        names_buttons.append(name)
print(urls_buttons,names_buttons)
# Out:
# ['https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#15.0/10.15426/76.39721', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.8/28.56281/77.09934', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.8/28.54713/77.08576', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.33/15.382536/73.830924', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#15.53/26.827761/75.807203', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2024-22%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrsw_c2s_2224#15.5/21.18356/81.743677', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.65/22.330402/73.22134', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/20.82158/86.96915', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/22.54158/88.30839', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/14.25306/80.1201', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.0/18.9597/72.94179'] ['Cochin_air', 'Delhi_air_a', 'Delhi_air_b', 'Dabolim_goa_air', 'Jaipur_air', 'Raipur_air', 'Vadodara_air', 'Dhamara_odisha_sea', 'Kolkata_sea', 'Krishnapatnam_andhra_sea', 'Mumbai_jawaharlal_sea']

# %%
capture_multiple_bhuvan_with_button(urls_buttons, names_buttons, output_dir='screenshots_layered')
# Out:
# 📷 Starting Bhuvan screenshot capture with button click...
#
# 📍 Processing 1/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#15.0/10.15426/76.39721
# ✅ Saved canvas screenshot: screenshots_layered\Cochin_air.png
#
# 📍 Processing 2/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.8/28.56281/77.09934
# ✅ Saved canvas screenshot: screenshots_layered\Delhi_air_a.png
#
# 📍 Processing 3/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.8/28.54713/77.08576
# ✅ Saved canvas screenshot: screenshots_layered\Delhi_air_b.png
#
# 📍 Processing 4/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.33/15.382536/73.830924
# ✅ Saved canvas screenshot: screenshots_layered\Dabolim_goa_air.png
#
# 📍 Processing 5/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#15.53/26.827761/75.807203
# ✅ Saved canvas screenshot: screenshots_layered\Jaipur_air.png
#
# 📍 Processing 6/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2024-22%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrsw_c2s_2224#15.5/21.18356/81.743677
# ✅ Saved canvas screenshot: screenshots_layered\Raipur_air.png
#
# 📍 Processing 7/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.65/22.330402/73.22134
# ✅ Saved canvas screenshot: screenshots_layered\Vadodara_air.png
#
# 📍 Processing 8/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/20.82158/86.96915
# ✅ Saved canvas screenshot: screenshots_layered\Dhamara_odisha_sea.png
#
# 📍 Processing 9/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/22.54158/88.30839
# ✅ Saved canvas screenshot: screenshots_layered\Kolkata_sea.png
#
# 📍 Processing 10/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/14.25306/80.1201
# ✅ Saved canvas screenshot: screenshots_layered\Krishnapatnam_andhra_sea.png
#
# 📍 Processing 11/11: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.0/18.9597/72.94179
# ✅ Saved canvas screenshot: screenshots_layered\Mumbai_jawaharlal_sea.png
#
# 🎉 All screenshots captured and browser closed.

# %%
capture_multiple_bhuvan_with_button(['https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.8/28.54713/77.08576'], ['Delhi_air_b'], output_dir='screenshots_layered')
# Out:
# 📷 Starting Bhuvan screenshot capture with button click...
#
# 📍 Processing 1/1: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#14.8/28.54713/77.08576
# ✅ Saved canvas screenshot: screenshots_layered\Delhi_air_b.png
#
# 🎉 All screenshots captured and browser closed.

# %%
df_17= pd.read_excel("Required data list new.xlsx")
df_17.head()
# Out:
#             City     Type   Latitude  Longitude   Zoom   Drop     Num  \
# 0   Ahmedbad_air  Airport  23.071908  72.622873  15.33  False     NaN
# 1  Bengaluru_air  Airport  13.201950  77.701164  15.20  False     NaN
# 2    Chennai_air  Airport  12.988160  80.167310  15.00  False     NaN
# 3     Cochin_air  Airport  10.154260  76.397210  15.00   True  2025.0
# 4    Delhi_air_a  Airport  28.562810  77.099340  14.80   True  2025.0
#
#                                           link_layer
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  &layer2=High+Resolution+Data+(1m)%3AJAN-JUN+20...
# 4  &layer2=High+Resolution+Data+(1m)%3AJAN-JUN+20...

# %%
url = 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#'
urls_17=[]
names_17=[]
for Lat,Long,drop,zoom,name in zip(df_17['Latitude'],df_17['Longitude'],df_17['Drop'],df_17['Zoom'],df_17['City']):
    url_i = url +str(zoom)+ '/' + str(Lat) + '/' + str(Long)
    urls_17.append(url_i)
    names_17.append(name)
print(urls_17,names_17)
# Out:
# ['https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.33/23.071908/72.622873', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.2/13.20195/77.701164', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/12.98816/80.16731', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/10.15426/76.39721', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.8/28.56281/77.09934', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.8/28.54713/77.08576', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.3/17.234269/78.436037', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.8/22.64575/88.44829', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/19.09157/72.86411', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/8.48229/76.92321', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.33/15.382536/73.830924', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.33/26.763504/80.888015', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.67/26.105694/91.584481', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.53/26.827761/75.807203', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.5/20.250122/85.816693', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.2/34.000663/74.761732', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.2/30.676495/76.786808', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.48/25.450904/82.857867', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHu ...

# %%
capture_multiple_bhuvan_with_button(urls_17, names_17, output_dir='screenshots_layered_17')
# Out:
# 📷 Starting Bhuvan screenshot capture with button click...
#
# 📍 Processing 1/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.33/23.071908/72.622873
# ✅ Saved canvas screenshot: screenshots_layered_17\Ahmedbad_air.png
#
# 📍 Processing 2/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.2/13.20195/77.701164
# ✅ Saved canvas screenshot: screenshots_layered_17\Bengaluru_air.png
#
# 📍 Processing 3/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/12.98816/80.16731
# ✅ Saved canvas screenshot: screenshots_layered_17\Chennai_air.png
#
# 📍 Processing 4/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/10.15426/76.39721
# ✅ Saved canvas screenshot: screenshots_layered_17\Cochin_air.png
#
# 📍 Processing 5/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.8/28.56281/77.09934
# ✅ Saved canvas screenshot: screenshots_layered_17\Delhi_air_a.png
#
# 📍 Processing 6/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.8/28.54713/77.08576
# ✅ Saved canvas screenshot: screenshots_layered_17\Delhi_air_b.png
#
# 📍 Processing 7/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.3/17.234269/78.436037
# ✅ Saved canvas screenshot: screenshots_layered_17\Hyderabad_air.png
#
# 📍 Processing 8/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.8/22.64575/88.44829
# ✅ Saved canvas screenshot: screenshots_layered_17\Kolkata_air.png
#
# 📍 Processing 9/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/19.09157/72.86411
# ✅ Saved canvas screenshot: screenshots_layered_17\Mumbai_air.png
#
# 📍 Processing 10/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/8.48229/76.92321
# ✅ Saved canvas screenshot: screenshots_layered_17\Thiruvananthpuram_air.png
#
# 📍 Processing 11/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.33/15.382536/73.830924
# ✅ Saved canvas screenshot: screenshots_layered_17\Dabolim_goa_air.png
#
# 📍 Processing 12/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.33/26.763504/80.888015
# ✅ Saved canvas screenshot: screenshots_layered_17\Lucknow_air.png
#
# 📍 Processing 13/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.67/26.105694/91.584481
# ✅ Saved canvas screenshot: screenshots_layered_17\Guwahati_air.png
#
# 📍 Processing 14/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.53/26.827761/75.807203
# ✅ Saved canvas screenshot: screenshots_layered_17\Jaipur_air.png
#
# 📍 Processing 15/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.5/20.250122/85.816693
# ✅ Saved canvas screenshot: screenshots_layered_17\Bhubaneswar_air.png
#
# 📍 Processing 16/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.2/34.000663/74.761732
# ✅ Saved canvas screenshot: screenshots_layered_17\Srinagar_air.png
#
# 📍 Processing 17/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.2/30.676495/76.786808
# ✅ Saved canvas screenshot: screenshots_layered_17\Chandigarh_air.png
#
# 📍 Processing 18/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.48/25.450904/82.857867
# ✅ Saved canvas screenshot: screenshots_layered_17\Varanasi_air.png
#
# 📍 Processing 19/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.57/25.593168/85.090986
# ✅ Saved canvas screenshot: screenshots_layered_17\Patna_air.png
#
# 📍 Processing 20/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.73/22.725949/75.805729
# ✅ Saved canvas screenshot: screenshots_layered_17\Indore_air.png
#
# 📍 Processing 21/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.5/11.138682/75.950432
# ✅ Saved canvas screenshot: screenshots_layered_17\Kozhikode_air.png
#
# 📍 Processing 22/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.81/11.028628/77.04305
# ✅ Saved canvas screenshot: screenshots_layered_17\Coimbatore_air.png
#
# 📍 Processing 23/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.6/26.68446/88.3268
# ✅ Saved canvas screenshot: screenshots_layered_17\Siligudi_air.png
#
# 📍 Processing 24/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.67/21.119658/72.745755
# ✅ Saved canvas screenshot: screenshots_layered_17\Surat_air.png
#
# 📍 Processing 25/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.76/24.618861/73.895636
# ✅ Saved canvas screenshot: screenshots_layered_17\Udaipur_air.png
#
# 📍 Processing 26/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.8/23.288095/77.33874
# ✅ Saved canvas screenshot: screenshots_layered_17\Bhopal_air.png
#
# 📍 Processing 27/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.5/21.18356/81.743677
# ✅ Saved canvas screenshot: screenshots_layered_17\Raipur_air.png
#
# 📍 Processing 28/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.57/23.888891/91.242379
# ✅ Saved canvas screenshot: screenshots_layered_17\Agartala_air.png
#
# 📍 Processing 29/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.4/32.683019/74.840734
# ✅ Saved canvas screenshot: screenshots_layered_17\Jammu_air.png
#
# 📍 Processing 30/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.67/24.764173/93.898159
# ✅ Saved canvas screenshot: screenshots_layered_17\Imphal_air.png
#
# 📍 Processing 31/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.8/9.835729/78.090528
# ✅ Saved canvas screenshot: screenshots_layered_17\Madurai_air.png
#
# 📍 Processing 32/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.64/16.525919/80.794677
# ✅ Saved canvas screenshot: screenshots_layered_17\Vijaywada_air.png
#
# 📍 Processing 33/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.65/22.330402/73.22134
# ✅ Saved canvas screenshot: screenshots_layered_17\Vadodara_air.png
#
# 📍 Processing 34/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/13.10617/80.30735
# ✅ Saved canvas screenshot: screenshots_layered_17\Chennai_sea_a.png
#
# 📍 Processing 35/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/13.09309/80.30023
# ✅ Saved canvas screenshot: screenshots_layered_17\Chennai_sea_b.png
#
# 📍 Processing 36/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/9.96381/76.27508
# ✅ Saved canvas screenshot: screenshots_layered_17\Cochin_sea_a.png
#
# 📍 Processing 37/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/9.95064/76.28014
# ✅ Saved canvas screenshot: screenshots_layered_17\Cochin_sea_b.png
#
# 📍 Processing 38/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/20.82158/86.96915
# ✅ Saved canvas screenshot: screenshots_layered_17\Dhamara_odisha_sea.png
#
# 📍 Processing 39/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/13.26656/80.34247
# ✅ Saved canvas screenshot: screenshots_layered_17\Ennore_sea.png
#
# 📍 Processing 40/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.7/22.0324/88.0877
# ✅ Saved canvas screenshot: screenshots_layered_17\Haldia_bengal_sea.png
#
# 📍 Processing 41/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/21.08194/72.62987
# ✅ Saved canvas screenshot: screenshots_layered_17\Hazira_guj_sea.png
#
# 📍 Processing 42/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/23.02674/70.22894
# ✅ Saved canvas screenshot: screenshots_layered_17\Kandla_Gujrat_sea_a.png
#
# 📍 Processing 43/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/23.00914/70.22968
# ✅ Saved canvas screenshot: screenshots_layered_17\Kandla_Gujrat_sea_b.png
#
# 📍 Processing 44/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/22.98751/70.23195
# ✅ Saved canvas screenshot: screenshots_layered_17\Kandla_Gujrat_sea_c.png
#
# 📍 Processing 45/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/22.54158/88.30839
# ✅ Saved canvas screenshot: screenshots_layered_17\Kolkata_sea.png
#
# 📍 Processing 46/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/14.25306/80.1201
# ✅ Saved canvas screenshot: screenshots_layered_17\Krishnapatnam_andhra_sea.png
#
# 📍 Processing 47/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.9/12.9256/74.82512
# ✅ Saved canvas screenshot: screenshots_layered_17\Mangalore_new_sea.png
#
# 📍 Processing 48/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/15.4088/73.80111111
# ✅ Saved canvas screenshot: screenshots_layered_17\Mormugao_Goa_sea.png
#
# 📍 Processing 49/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.0/18.9597/72.94179
# ✅ Saved canvas screenshot: screenshots_layered_17\Mumbai_jawaharlal_sea.png
#
# 📍 Processing 50/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.2/18.89497/72.85915
# ✅ Saved canvas screenshot: screenshots_layered_17\Mumbai_sea_a.png
#
# 📍 Processing 51/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.17/18.942544/72.842736
# ✅ Saved canvas screenshot: screenshots_layered_17\Mumbai_sea_b.png
#
# 📍 Processing 52/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#14.5/22.73979/69.70958
# ✅ Saved canvas screenshot: screenshots_layered_17\Mundra_guj_sea.png
#
# 📍 Processing 53/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/20.2754/86.67236
# ✅ Saved canvas screenshot: screenshots_layered_17\Paradeep_Odisha_sea_a.png
#
# 📍 Processing 54/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/20.25964/86.67534
# ✅ Saved canvas screenshot: screenshots_layered_17\Paradeep_Odisha_sea_b.png
#
# 📍 Processing 55/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/21.08/72.63
# ✅ Saved canvas screenshot: screenshots_layered_17\Surat_sea.png
#
# 📍 Processing 56/56: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#15.0/17.70101/83.28327
# ✅ Saved canvas screenshot: screenshots_layered_17\Vishakhapatanam_sea.png
#
# 🎉 All screenshots captured and browser closed.

# %%
url = 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#'
urls=[]
names=[]
for Lat,Long,drop,zoom,name,types in zip(df['Latitude'],df['Longitude'],df['Drop'],df['Zoom'],df['City'],df['Type']):
    if drop == False and types == 'Airport' :
        zoom +=1
        url_i = url +str(zoom)+ '/' + str(Lat) + '/' + str(Long)
        urls.append(url_i)
        names.append(name)
print(urls,names)
urls_air=urls
# Out:
# ['https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.33/23.071908/72.622873', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.2/13.20195/77.701164', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.0/12.98816/80.16731', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.3/17.234269/78.436037', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.8/22.64575/88.44829', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.0/19.09157/72.86411', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.0/8.48229/76.92321', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.33/26.763504/80.888015', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.67/26.105694/91.584481', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.5/20.250122/85.816693', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.2/34.000663/74.761732', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.2/30.676495/76.786808', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.48/25.450904/82.857867', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.57/25.593168/85.090986', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.73/22.725949/75.805729', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.5/11.138682/75.950432', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.810000000000002/11.028628/77.04305', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.6/26.68446/88.3268', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.67/21.119658/72.745755', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.759999999999998/24.618861/73.895636', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.8/23.288095/77.33874', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.57/23.888891/91.242379', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.4/32.683019/74.840734', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.67/24.764173/93.898159', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.8/9.835729/78.090528', 'https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.64/16.525919/80.794677'] ['Ahmedbad_air', 'Bengaluru_air', 'Chennai_air', 'Hyderabad_air', 'Kolkata_air', 'Mumbai_air', 'Thiruvananthpuram_air', 'Lucknow_air', 'Guwahati_air', 'Bhubaneswar_air', 'Srinagar_air', 'Chandigarh_air', 'Varanasi_air', 'Patna_air', 'Indore_air', 'Kozhikode_air', 'Coimbatore_air', 'Siligudi_air', 'Surat_air', 'Udaipur_air', 'Bhopal_air', 'Agartala_air', 'Jammu_air', 'Imphal_air', 'Madurai_air', 'Vijaywada_air']

# %%
len(urls)
# Out:
# 26

# %%
capture_multiple_bhuvan_screenshots(urls_air,names, output_dir='screenshots_air_zoom')
# Out:
# 📍 Processing 1/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.33/23.071908/72.622873
# ✅ Saved canvas screenshot: screenshots_air_zoom\Ahmedbad_air.png
#
# 📍 Processing 2/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.2/13.20195/77.701164
# ✅ Saved canvas screenshot: screenshots_air_zoom\Bengaluru_air.png
#
# 📍 Processing 3/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.0/12.98816/80.16731
# ✅ Saved canvas screenshot: screenshots_air_zoom\Chennai_air.png
#
# 📍 Processing 4/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.3/17.234269/78.436037
# ✅ Saved canvas screenshot: screenshots_air_zoom\Hyderabad_air.png
#
# 📍 Processing 5/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#15.8/22.64575/88.44829
# ✅ Saved canvas screenshot: screenshots_air_zoom\Kolkata_air.png
#
# 📍 Processing 6/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.0/19.09157/72.86411
# ✅ Saved canvas screenshot: screenshots_air_zoom\Mumbai_air.png
#
# 📍 Processing 7/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.0/8.48229/76.92321
# ✅ Saved canvas screenshot: screenshots_air_zoom\Thiruvananthpuram_air.png
#
# 📍 Processing 8/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.33/26.763504/80.888015
# ✅ Saved canvas screenshot: screenshots_air_zoom\Lucknow_air.png
#
# 📍 Processing 9/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.67/26.105694/91.584481
# ✅ Saved canvas screenshot: screenshots_air_zoom\Guwahati_air.png
#
# 📍 Processing 10/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.5/20.250122/85.816693
# ✅ Saved canvas screenshot: screenshots_air_zoom\Bhubaneswar_air.png
#
# 📍 Processing 11/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.2/34.000663/74.761732
# ✅ Saved canvas screenshot: screenshots_air_zoom\Srinagar_air.png
#
# 📍 Processing 12/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.2/30.676495/76.786808
# ✅ Saved canvas screenshot: screenshots_air_zoom\Chandigarh_air.png
#
# 📍 Processing 13/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.48/25.450904/82.857867
# ✅ Saved canvas screenshot: screenshots_air_zoom\Varanasi_air.png
#
# 📍 Processing 14/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.57/25.593168/85.090986
# ✅ Saved canvas screenshot: screenshots_air_zoom\Patna_air.png
#
# 📍 Processing 15/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.73/22.725949/75.805729
# ✅ Saved canvas screenshot: screenshots_air_zoom\Indore_air.png
#
# 📍 Processing 16/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.5/11.138682/75.950432
# ✅ Saved canvas screenshot: screenshots_air_zoom\Kozhikode_air.png
#
# 📍 Processing 17/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.810000000000002/11.028628/77.04305
# ✅ Saved canvas screenshot: screenshots_air_zoom\Coimbatore_air.png
#
# 📍 Processing 18/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.6/26.68446/88.3268
# ✅ Saved canvas screenshot: screenshots_air_zoom\Siligudi_air.png
#
# 📍 Processing 19/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.67/21.119658/72.745755
# ✅ Saved canvas screenshot: screenshots_air_zoom\Surat_air.png
#
# 📍 Processing 20/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.759999999999998/24.618861/73.895636
# ✅ Saved canvas screenshot: screenshots_air_zoom\Udaipur_air.png
#
# 📍 Processing 21/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.8/23.288095/77.33874
# ✅ Saved canvas screenshot: screenshots_air_zoom\Bhopal_air.png
#
# 📍 Processing 22/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.57/23.888891/91.242379
# ✅ Saved canvas screenshot: screenshots_air_zoom\Agartala_air.png
#
# 📍 Processing 23/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.4/32.683019/74.840734
# ✅ Saved canvas screenshot: screenshots_air_zoom\Jammu_air.png
#
# 📍 Processing 24/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.67/24.764173/93.898159
# ✅ Saved canvas screenshot: screenshots_air_zoom\Imphal_air.png
#
# 📍 Processing 25/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.8/9.835729/78.090528
# ✅ Saved canvas screenshot: screenshots_air_zoom\Madurai_air.png
#
# 📍 Processing 26/26: https://bhuvan.nrsc.gov.in/ngmaps?mode=Satellite#16.64/16.525919/80.794677
# ✅ Saved canvas screenshot: screenshots_air_zoom\Vijaywada_air.png
#
#  All screenshots captured and browser closed.

# %%
url = 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite'
urls_buttons_air=[]
names_buttons=[]
for idx,row in df.iterrows():
        if row['Drop'] == True and row['Type'] == 'Airport':
            zoom = row['Zoom']+1
            Lat=row['Latitude']
            Long=row['Longitude']
            url_i = url + row['link_layer'] +'#'+str(zoom)+ '/' + str(Lat) + '/' + str(Long)
            urls_buttons_air.append(url_i)
            names_buttons.append(row['City'])

print(urls_buttons_air,names_buttons)
# Out:
# ['https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#16.0/10.15426/76.39721', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#15.8/28.56281/77.09934', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#15.8/28.54713/77.08576', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#16.33/15.382536/73.830924', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#16.53/26.827761/75.807203', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2024-22%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrsw_c2s_2224#16.5/21.18356/81.743677', 'https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#16.65/22.330402/73.22134'] ['Cochin_air', 'Delhi_air_a', 'Delhi_air_b', 'Dabolim_goa_air', 'Jaipur_air', 'Raipur_air', 'Vadodara_air']

# %%
capture_multiple_bhuvan_with_button(urls_buttons_air, names_buttons, output_dir='screenshots_air_zoom')
# Out:
# Starting Bhuvan screenshot capture with button click...
#
# 📍 Processing 1/7: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#16.0/10.15426/76.39721
# ✅ Saved canvas screenshot: screenshots_air_zoom\Cochin_air.png
#
# 📍 Processing 2/7: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#15.8/28.56281/77.09934
# ✅ Saved canvas screenshot: screenshots_air_zoom\Delhi_air_a.png
#
# 📍 Processing 3/7: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#15.8/28.54713/77.08576
# ✅ Saved canvas screenshot: screenshots_air_zoom\Delhi_air_b.png
#
# 📍 Processing 4/7: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#16.33/15.382536/73.830924
# ✅ Saved canvas screenshot: screenshots_air_zoom\Dabolim_goa_air.png
#
# 📍 Processing 5/7: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3AJAN-JUN+2025%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrs_25rw#16.53/26.827761/75.807203
# ✅ Saved canvas screenshot: screenshots_air_zoom\Jaipur_air.png
#
# 📍 Processing 6/7: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2024-22%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2Ftilecache%2Ftilecache.py%24hrsw_c2s_2224#16.5/21.18356/81.743677
# ✅ Saved canvas screenshot: screenshots_air_zoom\Raipur_air.png
#
# 📍 Processing 7/7: https://bhuvan.nrsc.gov.in/ngmaps/science?dataHubTab=0&mode=Satellite&layer2=High+Resolution+Data+(1m)%3A2017%24https%3A%2F%2Fbhuvan-ras1.nrsc.gov.in%2FSatServices%2Fservice%24bhuvan_hrs_2017#16.65/22.330402/73.22134
# ✅ Saved canvas screenshot: screenshots_air_zoom\Vadodara_air.png
#
# 🎉 All screenshots captured and browser closed.
